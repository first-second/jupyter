# %%
from matplotlib import pyplot as plt

x=[1,2,3]
y=[6,3,9]
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

chart = pd.read_csv('/tmp/data1.csv')
df = pd.DataFrame(chart)
X = list(df.iloc[:,1])
Y = list(df.iloc[:,0])

plt.bar(X,Y, color='b')
plt.show()
