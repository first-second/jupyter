# %%
import pandas as pd
import matplotlib.pyplot as plt
import math

df=pd.read_excel("gold_new.xlsx")
print(df)
# Out:
#        Unnamed: 0       date     price  year  month   D
# 0               0 1982-07-01  178.7900  1982      7   1
# 1               1 1982-07-02  180.6500  1982      7   2
# 2               2 1982-07-06  180.4200  1982      7   6
# 3               3 1982-07-07  179.3000  1982      7   7
# 4               4 1982-07-08  183.2800  1982      7   8
# ...           ...        ...       ...   ...    ...  ..
# 34699       10470 2022-11-21   20.8415  2022     11  21
# 34700       10471 2022-11-22   21.0802  2022     11  22
# 34701       10472 2022-11-23   21.5144  2022     11  23
# 34702       10473 2022-11-24   21.5100  2022     11  24
# 34703       10474 2022-11-25   21.5900  2022     11  25
#
# [34704 rows x 6 columns]

# %%
years=list(set(df['year']))

#print(years*365)

# %%
print(len(years)*365)
# Out:
# 20075

# %%
df.sort_values("date",inplace=True)
df=df.drop_duplicates(subset=["date"], keep=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_386627/2032646725.py in <module>
# ----> 1 df.sort_values("date",inplace=True)
#       2 df=df.drop_duplicates(subset=["date"], keep=False)
#
# AttributeError: 'NoneType' object has no attribute 'sort_values'

# %%
sorted_df = df.sort_values(by=['date'], ascending=True)
print(sorted_df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_386627/2582903268.py in <module>
# ----> 1 sorted_df = df.sort_values(by=['date'], ascending=True)
#       2 print(sorted_df)
#
# AttributeError: 'NoneType' object has no attribute 'sort_values'

# %%
sorted_df.to_excel("gold_sorted.xlsx")

# %%
df=pd.read_excel("gold_sorted.xlsx")

# %%
years=list(set(df['year']))

# %%
print(years)
print(len(years))
# Out:
# [1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1986, 1987, 1988, 1989, 2004, 2007, 2013, 2017, 2018]
# 24

# %%
years_count=years[-1:-9:-1]
print(years_count)
for i in years_count:
    print(df[df['year']==i].count())
# Out:
# [2018, 2017, 2013, 2007, 2004, 1989, 1988, 1987]
# Unnamed: 0      3
# Unnamed: 0.1    3
# date            3
# price           3
# year            3
# month           3
# D               3
# dtype: int64
# Unnamed: 0      1
# Unnamed: 0.1    1
# date            1
# price           1
# year            1
# month           1
# D               1
# dtype: int64
# Unnamed: 0      1
# Unnamed: 0.1    1
# date            1
# price           1
# year            1
# month           1
# D               1
# dtype: int64
# Unnamed: 0      1
# Unnamed: 0.1    1
# date            1
# price           1
# year            1
# month           1
# D               1
# dtype: int64
# Unnamed: 0      1
# Unnamed: 0.1    1
# date            1
# price           1
# year            1
# month           1
# D               1
# dtype: int64
# Unnamed: 0      1
# Unnamed: 0.1    1
# date            1
# price           1
# year            1
# month           1
# D               1
# dtype: int64
# Unnamed: 0      2
# Unnamed: 0.1    2
# date            2
# price           2
# year            2
# month           2
# D               2
# dtype: int64
# Unnamed: 0      2
# Unnamed: 0.1    2
# date            2
# price           2
# year            2
# month           2
# D               2
# dtype: int64

# %%
import numpy as np
import math
figure, axis = plt.subplots(2, 4,figsize=(25, 25))
for i in range(len(ans)):
    x=0
    while(x<2):
        j=0
        while(j<4):
            axis[x,j].plot(ans[i]['month'],ans[i]['price'])
            axis[x,j].set_title("year {0}".format(i))
            j+=1
        x+=1
plt.show()
